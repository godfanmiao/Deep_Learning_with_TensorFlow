# %%
import tensorflow as tf
import matplotlib
matplotlib.use('nbagg')

# %%
from tensorflow.examples.tutorials.mnist import input_data
import matplotlib.pyplot as plt

# %%
mnist = input_data.read_data_sets('MNIST_data/', one_hot=True)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
print mnist.train.images.shape, mnist.train.labels.shape
print mnist.validation.images.shape, mnist.validation.labels.shape
print mnist.test.images.shape, mnist.test.labels.shape
# Out:
# (55000, 784) (55000, 10)
# (5000, 784) (5000, 10)
# (10000, 784) (10000, 10)

# %%
TRAINING_ITER = 5000
BATCH_SIZE = 100
INPUT_UNITS = 784
HIDDEN_UNITS = 256
N_CLASSES = 10
LEARNING_RATE = 0.5

def init_weights(shape):
    return tf.Variable(tf.random_normal(shape))

def init_biases(shape):
    return tf.Variable(tf.zeros(shape) + 0.1)

def add_layer(x, weights, biases, activation_function=None):
    score = tf.matmul(x, weights) + biases
    if activation_function:
        return activation_function(score)
    else:
        return score

# %%
x = tf.placeholder(tf.float32, [None, INPUT_UNITS])
y = tf.placeholder(tf.float32, [None, N_CLASSES])

weights = {'l1': init_weights([INPUT_UNITS, HIDDEN_UNITS]), 'l2': init_weights([HIDDEN_UNITS, N_CLASSES])}
biases = {'l1': init_biases([HIDDEN_UNITS]), 'l2': init_biases([N_CLASSES])}

h1 = add_layer(x, weights['l1'], biases['l1'], tf.nn.tanh)

predictions = add_layer(h1, weights['l2'], biases['l2'], None)

loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=predictions, labels=y))

train_step = tf.train.GradientDescentOptimizer(LEARNING_RATE).minimize(loss)

accuracy = tf.reduce_mean(tf.cast(tf.equal(tf.arg_max(y, 1), tf.arg_max(predictions, 1)), tf.float32))

# %%
init = tf.global_variables_initializer()

train_acc = []
valid_acc = []
epoch = []

with tf.Session() as sess:
    sess.run(init)
    
    for i in range(TRAINING_ITER):
        batch_xs, batch_ys = mnist.train.next_batch(BATCH_SIZE)
        
        sess.run(train_step, feed_dict = {x: batch_xs, y: batch_ys})
        
        if i % 50 == 0:
            epoch.append(i)
            
            train_accuracy = sess.run(accuracy, feed_dict = {x: batch_xs, y: batch_ys})
            print 'TRAIN_ACC@%d' %i, train_accuracy
            train_acc.append(train_accuracy)
            
            valid_accuracy = sess.run(accuracy, feed_dict = {x: mnist.validation.images, y: mnist.validation.labels})
            print 'VALID_ACC@%d' %i, valid_accuracy
            valid_acc.append(valid_accuracy)
            
    print 'TEST_ACC', sess.run(accuracy, feed_dict = {x: mnist.test.images, y: mnist.test.labels})
# Out:
# TRAIN_ACC@0 0.35
# VALID_ACC@0 0.1746
# TRAIN_ACC@50 0.9
# VALID_ACC@50 0.7546
# TRAIN_ACC@100 0.9
# VALID_ACC@100 0.7974
# TRAIN_ACC@150 0.87
# VALID_ACC@150 0.8414
# TRAIN_ACC@200 0.95
# VALID_ACC@200 0.8536
# TRAIN_ACC@250 0.91
# VALID_ACC@250 0.85
# TRAIN_ACC@300 0.97
# VALID_ACC@300 0.868
# TRAIN_ACC@350 0.92
# VALID_ACC@350 0.8716
# TRAIN_ACC@400 0.92
# VALID_ACC@400 0.8836
# TRAIN_ACC@450 0.95
# VALID_ACC@450 0.8882
# TRAIN_ACC@500 0.94
# VALID_ACC@500 0.8836
# TRAIN_ACC@550 0.97
# VALID_ACC@550 0.9038
# TRAIN_ACC@600 0.95
# VALID_ACC@600 0.9024
# TRAIN_ACC@650 0.98
# VALID_ACC@650 0.8962
# TRAIN_ACC@700 0.96
# VALID_ACC@700 0.8912
# TRAIN_ACC@750 0.93
# VALID_ACC@750 0.9032
# TRAIN_ACC@800 0.97
# VALID_ACC@800 0.9052
# TRAIN_ACC@850 0.97
# VALID_ACC@850 0.902
# TRAIN_ACC@900 0.99
# VALID_ACC@900 0.9062
# TRAIN_ACC@950 0.98
# VALID_ACC@950 0.9032
# TRAIN_ACC@1000 0.98
# VALID_ACC@1000 0.9142
# TRAIN_ACC@1050 0.95
# VALID_ACC@1050 0.9108
# TRAIN_ACC@1100 0.96
# VALID_ACC@1100 0.9144
# TRAIN_ACC@1150 0.99
# VALID_ACC@1150 0.9162
# TRAIN_ACC@1200 0.96
# VALID_ACC@1200 0.9094
# TRAIN_ACC@1250 0.95
# VALID_ACC@1250 0.9112
# TRAIN_ACC@1300 0.99
# VALID_ACC@1300 0.9136
# TRAIN_ACC@1350 0.99
# VALID_ACC@1350 0.9128
# TRAIN_ACC@1400 0.95
# VALID_ACC@1400 0.916
# TRAIN_ACC@1450 0.99
# VALID_ACC@1450 0.916
# TRAIN_ACC@1500 0.99
# VALID_ACC@1500 0.918
# TRAIN_ACC@1550 0.94
# VALID_ACC@1550 0.9182
# TRAIN_ACC@1600 0.94
# VALID_ACC@1600 0.9184
# TRAIN_ACC@1650 0.98
# VALID_ACC@1650 0.9222
# TRAIN_ACC@1700 1.0
# VALID_ACC@1700 0.9204
# TRAIN_ACC@1750 0.96
# VALID_ACC@1750 0.9146
# TRAIN_ACC@1800 1.0
# VALID_ACC@1800 0.9222
# TRAIN_ACC@1850 0.99
# VALID_ACC@1850 0.9262
# TRAIN_ACC@1900 0.96
# VALID_ACC@1900 0.9184
# TRAIN_ACC@1950 1.0
# VALID_ACC@1950 0.926
# TRAIN_ACC@2000 0.96
# VALID_ACC@2000 0.9208
# TRAIN_ACC@2050 0.98
# VALID_ACC@2050 0.9254
# TRAIN_ACC@2100 0.98
# VALID_ACC@2100 0.9228
# TRAIN_ACC@2150 0.96
# VALID_ACC@2150 0.9236
# TRAIN_ACC@2200 0.98
# VALID_ACC@2200 0.9286
# TRAIN_ACC@2250 0.99
# VALID_ACC@2250 0.9232
# TRAIN_ACC@2300 1.0
# VALID_ACC@2300 0.9222
# TRAIN_ACC@2350 1.0
# VALID_ACC@2350 0.925
# TRAIN_ACC@2400 1.0
# VALID_ACC@2400 0.928
# TRAIN_ACC@2450 0.98
# VALID_ACC@2450 0.9176
# TRAIN_ACC@2500 0.98
# VALID_ACC@2500 0.927
# TRAIN_ACC@2550 0.97
# VALID_ACC@2550 0.925
# TRAIN_ACC@2600 0.98
# VALID_ACC@2600 0.9236
# TRAIN_ACC@2650 0.97
# VALID_ACC@2650 0.9254
# TRAIN_ACC@2700 0.98
# VALID_ACC@2700 0.9292
# TRAIN_ACC@2750 0.98
# VALID_ACC@2750 0.9294
# TRAIN_ACC@2800 0.97
# VALID_ACC@2800 0.9236
# TRAIN_ACC@2850 1.0
# VALID_ACC@2850 0.9276
# TRAIN_ACC@2900 0.99
# VALID_ACC@2900 0.9274
# TRAIN_ACC@2950 0.98
# VALID_ACC@2950 0.9288
# TRAIN_ACC@3000 0.99
# VALID_ACC@3000 0.9242
# TRAIN_ACC@3050 1.0
# VALID_ACC@3050 0.9294
# TRAIN_ACC@3100 0.99
# VALID_ACC@3100 0.9268
# TRAIN_ACC@3150 0.98
# VALID_ACC@3150 0.93
# TRAIN_ACC@3200 1.0
# VALID_ACC@3200 0.9328
# TRAIN_ACC@3250 0.96
# VALID_ACC@3250 0.9304
# TRAIN_ACC@3300 0.99
# VALID_ACC@3300 0.9326
# TRAIN_ACC@3350 0.99
# VALID_ACC@3350 0.9298
# TRAIN_ACC@3400 0.99
# VALID_ACC@3400 0.9316
# TRAIN_ACC@3450 0.99
# VALID_ACC@3450 0.9274
# TRAIN_ACC@3500 0.99
# VALID_ACC@3500 0.9266
# TRAIN_ACC@3550 0.99
# VALID_ACC@3550 0.9296
# TRAIN_ACC@3600 0.99
# VALID_ACC@3600 0.9322
# TRAIN_ACC@3650 0.99
# VALID_ACC@3650 0.93
# TRAIN_ACC@3700 0.99
# VALID_ACC@3700 0.9306
# TRAIN_ACC@3750 0.99
# VALID_ACC@3750 0.9312
# TRAIN_ACC@3800 1.0
# VALID_ACC@3800 0.9292
# TRAIN_ACC@3850 1.0
# VALID_ACC@3850 0.9328
# TRAIN_ACC@3900 0.99
# VALID_ACC@3900 0.9314
# TRAIN_ACC@3950 0.98
# VALID_ACC@3950 0.9294
# TRAIN_ACC@4000 0.99
# VALID_ACC@4000 0.9326
# TRAIN_ACC@4050 0.99
# VALID_ACC@4050 0.9342
# TRAIN_ACC@4100 1.0
# VALID_ACC@4100 0.9312
# TRAIN_ACC@4150 1.0
# VALID_ACC@4150 0.9332
# TRAIN_ACC@4200 0.98
# VALID_ACC@4200 0.9322
# TRAIN_ACC@4250 1.0
# VALID_ACC@4250 0.9334
# TRAIN_ACC@4300 1.0
# VALID_ACC@4300 0.9302
# TRAIN_ACC@4350 0.99
# VALID_ACC@4350 0.9308
# TRAIN_ACC@4400 0.99
# VALID_ACC@4400 0.9318
# TRAIN_ACC@4450 1.0
# VALID_ACC@4450 0.9328
# TRAIN_ACC@4500 1.0
# VALID_ACC@4500 0.9324
# TRAIN_ACC@4550 0.99
# VALID_ACC@4550 0.929
# TRAIN_ACC@4600 0.98
# VALID_ACC@4600 0.9334
# TRAIN_ACC@4650 1.0
# VALID_ACC@4650 0.933
# TRAIN_ACC@4700 0.99
# VALID_ACC@4700 0.9322
# TRAIN_ACC@4750 0.99
# VALID_ACC@4750 0.9296
# TRAIN_ACC@4800 0.98
# VALID_ACC@4800 0.9328
# TRAIN_ACC@4850 0.99
# VALID_ACC@4850 0.9344
# TRAIN_ACC@4900 0.99
# VALID_ACC@4900 0.9362
# TRAIN_ACC@4950 1.0
# VALID_ACC@4950 0.9376
# TEST_ACC 0.9343

# %%
plt.plot(epoch, train_acc, 'r-')
plt.plot(epoch, valid_acc, 'g-')
plt.title('MNIST_MLN_CLASSIFIER')
plt.xlabel('EPOCH')
plt.ylabel('ACCURACY')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
